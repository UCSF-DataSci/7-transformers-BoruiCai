# %% [markdown]
# # Part 3: Prompt Engineering Basics
#
# ## Introduction
#
# In this part, you'll experiment with different prompting techniques to improve the quality of responses from Large Language Models (LLMs). You'll compare zero-shot, one-shot, and few-shot prompting approaches and document which works best for different types of questions.
#
# ## Learning Objectives
#
# - Understand different prompting techniques
# - Compare zero-shot, one-shot, and few-shot prompting
# - Analyze the impact of prompt design on response quality
#
# ## Setup

# %%
# Import necessary libraries
import requests
import json

# %% [markdown]
# ## 1. Understanding Prompting Techniques
#
# LLMs can be prompted in different ways to get better responses:
#
# 1. **Zero-shot prompting**: Asking the model a question directly without examples
# 2. **One-shot prompting**: Providing one example before asking your question
# 3. **Few-shot prompting**: Providing multiple examples before asking your question
#
# ## 2. Creating Prompting Templates
#
# Your first task is to create templates for different prompting strategies.

# %%
# Define a question to experiment with
question = "What foods should be avoided by patients with gout?"

# Example for one-shot and few-shot prompting
example_q = "What are the symptoms of gout?"
example_a = "Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe."

# Examples for few-shot prompting
examples = [
    ("What are the symptoms of gout?",
     "Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe."),
    ("How is gout diagnosed?",
     "Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.")
]

# TODO: Create prompting templates
# Zero-shot template (just the question)
zero_shot_template = "Question: {question}\nAnswer:"

# One-shot template (one example + the question)
one_shot_template = """Question: {example_q}
Answer: {example_a}

Question: {question}
Answer:"""

# Few-shot template (multiple examples + the question)
few_shot_template = """Question: {examples[0][0]}
Answer: {examples[0][1]}

Question: {examples[1][0]}
Answer: {examples[1][1]}

Question: {question}
Answer:"""

# TODO: Format the templates with your question and examples
zero_shot_prompt = zero_shot_template.format(question=question)
one_shot_prompt = one_shot_template.format(example_q=example_q, example_a=example_a, question=question)
# For few-shot, you'll need to format it with the examples list
few_shot_prompt = few_shot_template.format(examples=examples, question=question)

print("Zero-shot prompt:")
print(zero_shot_prompt)
print("\nOne-shot prompt:")
print(one_shot_prompt)
print("\nFew-shot prompt:")
print(few_shot_prompt)
# Out:
# Zero-shot prompt:
# Question: What foods should be avoided by patients with gout?
# Answer:
#
# One-shot prompt:
# Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: What foods should be avoided by patients with gout?
# Answer:
#
# Few-shot prompt:
# Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.
#
# Question: What foods should be avoided by patients with gout?
# Answer:

# %% [markdown]
# ## 3. Connecting to the LLM API
#
# Next, implement a function to send prompts to an LLM API and get responses.

# %%
# %pip install python-dotenv

import requests
from dotenv import load_dotenv
import os

load_dotenv("APIKEY.env")
api_key = os.getenv("HF_API_KEY")

def get_llm_response(prompt_text, model_name="HuggingFaceH4/zephyr-7b-beta", api_key=None):
    endpoint_url = f"https://api-inference.huggingface.co/models/{model_name}"
    headers = {"Authorization": f"Bearer {api_key}"} if api_key else {}
    payload = {
        "inputs": prompt_text,
        "parameters": {
            "max_new_tokens": 50 
        }
    }

    try:
        response = requests.post(endpoint_url, headers=headers, json=payload)
        response.raise_for_status()
        response_data = response.json()
        if isinstance(response_data, list) and "generated_text" in response_data[0]:
            return response_data[0]["generated_text"]
        else:
            return str(response_data)
    except Exception as error:
        return f"Error occurred: {error}"

prompt = "What is gout?"
output = get_llm_response(prompt_text=prompt, api_key=api_key)
print(output)

prompt = "What foods should be avoided by patients with gout?"
output = get_llm_response(prompt_text=prompt, api_key=api_key)
print(output)
print(api_key)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\users\cbr98\appdata\roaming\python\python311\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# What is gout?
# Gout is a type of arthritis that is caused by a buildup of uric acid in the body. Uric acid is a waste product that is normally eliminated in urine. However, when the body produces too much ur
# What foods should be avoided by patients with gout?
#
# Gout is a type of arthritis that is caused by the buildup of uric acid in the body. This can lead to inflammation and pain in the joints, particularly in the big toe. Patients with
# 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

# %% [markdown]
# ## 4. Comparing Prompting Strategies
#
# Now, let's compare the different prompting strategies on a set of healthcare questions.

# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv("APIKEY.env")
key = os.getenv("HF_API_KEY")

# Set model
model = "HuggingFaceH4/zephyr-7b-beta"

# Set list of questions
qs = [
    "What foods should be avoided by patients with gout?",
    "What medications are commonly prescribed for gout?",
    "How can gout flares be prevented?",
    "Is gout related to diet?",
    "Can gout be cured permanently?"
]

# Set few-shot examples
exs = [
    ("What are the symptoms of gout?",
     "Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe."),
    ("How is gout diagnosed?",
     "Gout is diagnosed through physical exam, history, blood tests for uric acid, and joint fluid tests.")
]

# Compare zero-shot, one-shot, few-shot for each question
for q in qs:
    # Make zero-shot prompt
    z_prompt = f"Question: {q}\nAnswer:"
    
    # Make one-shot prompt
    one_prompt = f"Question: {exs[0][0]}\nAnswer: {exs[0][1]}\n\nQuestion: {q}\nAnswer:"
    
    # Make few-shot prompt
    few_prompt = (
        f"Question: {exs[0][0]}\nAnswer: {exs[0][1]}\n\n"
        f"Question: {exs[1][0]}\nAnswer: {exs[1][1]}\n\n"
        f"Question: {q}\nAnswer:"
    )

    # Send prompts to model
    url = f"https://api-inference.huggingface.co/models/{model}"
    head = {"Authorization": f"Bearer {key}"}
    
    print(f"\n----- Question: {q} -----\n")

    # Zero-shot
    z_res = requests.post(url, headers=head, json={"inputs": z_prompt})
    print("Zero-shot:\n", z_res.json()[0]['generated_text'].strip())

    # One-shot
    one_res = requests.post(url, headers=head, json={"inputs": one_prompt})
    print("\nOne-shot:\n", one_res.json()[0]['generated_text'].strip())

    # Few-shot
    few_res = requests.post(url, headers=head, json={"inputs": few_prompt})
    print("\nFew-shot:\n", few_res.json()[0]['generated_text'].strip())
# Out:
# ----- Question: What foods should be avoided by patients with gout? -----
#
# Zero-shot:
#  Question: What foods should be avoided by patients with gout?
# Answer: Patients with gout should limit their intake of foods that are high in purines, which can increase uric acid levels in the body and lead to gout flares. Foods to avoid or limit include organ meats (e.g., liver, kidney), game meats (e.g., venison, pheasant), anchovies, sardines, mackerel, herring, scallops, trout, mussels, and까반민 (fermented soybean product). It is, however, still okay to eat small amounts of these foods as part of a balanced diet. It is also recommended to avoid or limit alcoholic beverages, especially those with high purine content such as beer. Additionally, sugary drinks and processed foods should be consumed in moderation as they can contribute to weight gain, which is a risk factor for gout. (Produced by TOMOREN Monograph Team)
#
# One-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: What foods should be avoided by patients with gout?
# Answer: Patients with gout should limit or avoid foods that are high in purines, such as organ meats (e.g., liver, kidneys), red meat, and seafood (e.g., oily fish, shellfish), as well as alcohol, especially beer. They should also avoid sugary drinks and limit their intake of saturated and trans fats.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed based on the presentation of symptoms, including sudden severe joint pain, swelling, redness, and tenderness, and the presence of uric acid crystals in joint fluid or urine, as well as high uric acid levels in the blood. Imaging studies may also be used to confirm the diagnosis.
#
# Few-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical exam, history, blood tests for uric acid, and joint fluid tests.
#
# Question: What foods should be avoided by patients with gout?
# Answer: Patients with gout should limit alcohol, seafood, red meat, and sweetened beverages. High purine foods such as organ meats should be avoided. Limits on these foods may be recommended by your healthcare provider based on your medical condition and response to treatment.
#
# Question: What steps should a person with gout take during a gout attack? Answer: A person with gout should elevate, apply ice, or a damp, cool cloth, and take prescribed medications as directed.
#
# Question: What should be done to prevent future gout attacks? Answer: To help prevent future gout attacks, take prescribed medications as directed, maintain a healthy weight if overweight, limit alcohol intake, eat a balanced diet, and drink plenty of water. Limits on alcohol, meat, and seafood may be recommended by your healthcare provider based on your medical condition and response to treatment.
#
# Question: How important is it to monitor uric acid levels in gout patients?
# Answer: Uric acid levels should be monitored to ensure they are within a healthy range. Your healthcare provider can help determine when and how often uric acid tests should be performed based on your medical condition, treatment, and response to treatment.
#
# Question: What are potential complications of gout?
# Answer: Untreated or poorly controlled gout can lead to joint damage, kidney stones, kidney disease, and an increased risk of cardiovascular disease.
#
# Question: Why is dietary management important in managing gout?
# Answer: A healthy weight, along with a diet low in purine content, can help manage gout symptoms by maintaining healthy uric acid levels. This can reduce the risk of gout attacks and complications associated with gout.
#
# ----- Question: What medications are commonly prescribed for gout? -----
#
# Zero-shot:
#  Question: What medications are commonly prescribed for gout?
# Answer: The most commonly prescribed medications for gout are:
#
# 1) Nonsteroidal anti-inflammatory drugs (NSAIDs): These medications are used to relieve pain and inflammation during a gout attack. Examples include ibuprofen, naproxen, and indomethacin.
#
# 2) Colchicine: This medication is used to prevent and treat gout attacks. It also helps to reduce inflammation.
#
# 3) Corticosteroids: These medications can be taken orally or injected to help reduce inflammation and pain during a gout attack.
#
# 4) Allopurinol: This medication is used to lower the production of uric acid in the body. It is typically prescribed as a long-term treatment to prevent future gout attacks.
#
# 5) Febuxostat: This medication is also used to lower the production of uric acid in the body, and is a recommended treatment option for some people who do not respond to allopurinol.
#
# See more Drugs for Gout.
#
# One-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: What medications are commonly prescribed for gout?
# Answer: Colchicine is a medication used to treat gout attacks. Nonsteroidal anti-inflammatory drugs (NSAIDs) like ibuprofen, naproxen, and indomethacin are also commonly prescribed for gout pain.
#
# Question: How can medications contribute to gout attacks?
# Answer: Some medications, such as diuretics (water pills) and low dose aspirin, can increase the level of uric acid in the body and contribute to gout attacks.
#
# Question: What lifestyle changes can help prevent gout attacks?
# Answer: Losing weight, limiting alcohol intake (especially beverages high in purines like beer), and eating less red meat and seafood can help prevent gout attacks.
#
# Question: What should I do if I experience my first gout attack?
# Answer: If you experience sudden severe pain, swelling, redness, and tenderness in a joint, especially in the big toe, you may be having a gout attack. Contact your healthcare provider for diagnosis and treatment recommendations.
#
# Question: What is the connection between high uric acid levels and gout?
# Answer: High uric acid levels in the blood can lead to the formation of uric acid crystals in joints, resulting in the symptoms of gout.
#
# Question: How does lifestyle impact uric acid levels?
# Answer: Eating a diet rich in purines (especially red meat and seafood) and drinking sugary beverages can lead to higher uric acid levels, increasing the risk of gout. Losing weight, limiting alcohol intake, and avoiding excessive consumption of high-purine foods can help keep uric acid levels within a healthy range.
#
# Question: Can gout be managed without medication?
# Answer: Dietary and lifestyle changes can help manage gout without medication. Losing weight, limiting alcohol and high-purine food intake, and drinking plenty of water can help prevent gout attacks.
#
# Question: Is gout a common health issue?
# Answer: Gout is a relatively common health issue, affecting around 4% of the adult population in the US. Men are more likely to develop gout than women, and it becomes more common as people age.
#
# Question: How does the body normally break down purines?
# Answer: The body breaks down purines into uric acid, which is eliminated in urine. However, if the body produces too much uric acid or eliminates too little, uric acid can build up and form crystals in joints and other tissues, causing gout.
#
# Question: What is the connection between genetics and gout?
# Answer: Some people have a genetic predisposition to developing gout due to genetic variations in the genes involved in uric acid metabolism.
#
# Question: Can gout cause damage to joints over time?
# Answer: Chronic gout can lead to joint damage, including joint erosion and increased joint stiffness and deformity, leading to long-term disability.
#
# Question: Can gout be prevented altogether?
# Answer: While gout cannot be completely prevented, making lifestyle changes such as losing weight, limiting alcohol and purine-rich food intake, and drinking plenty of water can help reduce the risk of developing gout.
#
# Question: What are some common foods that are high in purines?
# Answer: Red meat, organ meat, seafood (especially shellfish), peas, beans, and some vegetables such as spinach and asparagus are high in purines.
#
# Question: Is it true that gout is more common in men than women? Why?
# Answer: Yes, gout is more common in men than women, with the highest prevalence in men over 70 years old. This may be due to several factors, including the tendency for men to eat more red meat and drink more beer, which can lead to higher uric acid levels. Additionally, women may have lower uric acid levels due to the protective effect of estrogen, which decreases after menopause, increasing the risk of gout in women.
#
# Question: Can stress trigger a gout attack?
# Answer: Stress is not directly related to gout attacks, but it can lead to unhealthy behaviors such as overeating or excessive alcohol consumption, which can increase the risk of gout attacks.
#
# Question: How long does it typically take to recover from a gout attack?
# Answer: The length of a gout attack depends on the person and the severity of the attack. Most acute attacks heal within a week or two, but some may last longer. Chronic gout, which involves recurrent attacks and joint damage, may require ongoing management.
#
# Question: Can gout be cured completely?
# Answer: While gout attacks can be treated and managed with medication, diet, and lifestyle changes, there is no cure for gout. Chronic gout can lead to long-term joint damage, but early detection and management can help prevent or minimize the damage.
#
# Few-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical exam, history, blood tests for uric acid, and joint fluid tests.
#
# Question: What medications are commonly prescribed for gout?
# Answer: Common gout medications include nonsteroidal anti-inflammatory drugs (NSAIDs), colchicine, corticosteroids, and uric acid-lowering drugs, such as febuxostat, allopurinol, and probenecid.
#
# Question: Should I limit my intake of uric acid-rich foods if I have gout?
# Answer: In addition to medication, reducing your intake of uric acid-rich foods can help manage gout. Foods to limit include organ meats, shellfish, and drinks sweetened with fruit sugar (fructose).
#
# Question: Can gout be prevented? What lifestyle changes should I make to lower my risk?
# Answer: Maintaining a healthy weight, staying hydrated, and limiting alcohol and foods high in purines and fructose can lower the risk of developing gout.
#
# Question: Are there alternative therapies for managing gout besides medication?
# Answer: Acupuncture, herbal remedies, dietary supplements, and lifestyle changes like exercise and weight loss can be used in addition to medication to manage gout, but it's essential to consult with a healthcare provider before trying any alternative therapies.
#
# Question: Is gout more common in men or women?
# Answer: While both men and women can get gout, it's more common in men, especially after age 30. However, after menopause, women become just as susceptible to gout as men.
#
# Question: Can gout be fatal?
# Answer: Gout itself is not fatal, but complications associated with gout, such as kidney stones, can be dangerous if left untreated.
#
# Question: Is gout hereditary?
# Answer: While genetics can play a role in the development of gout, most cases of gout are not directly inherited. However, certain inherited conditions like kidney disease and metabolic disorders increase the risk of developing gout.
#
# Question: How long does an acute gout attack last?
# Answer: Acute gout attacks usually last for 3-10 days, but some people can experience longer attacks or recurring attacks.
#
# ----- Question: How can gout flares be prevented? -----
#
# Zero-shot:
#  Question: How can gout flares be prevented?
# Answer: Although gout is commonly seen as a disease caused by eating and drinking too much, its relationship with diet is much more complicated than this. The fundamental catalyst for gout is the buildup of high levels of uric acid in the body, a condition known as hyperuricemia. Uric acid is a byproduct of the metabolic process of purines, which occur naturally in the body as well as in a variety of common foods. Normally, uric acid dissolves in the bloodstream and passes through the kidneys, where it is flushed out in the urine. But when uric acid levels get too high, the excess starts to crystalize in the joints, causing inflammation, intense pain, and other symptoms of gout.
# In order to prevent gout flares, it is recommended that individuals with this condition take these measures:
# 1. Maintain a healthy body weight: Being overweight increases uric acid levels in the body as well as the likelihood of developing diabetes and other common diseases associated with gout.
# 2. Eat a healthy diet: Along with high-purine foods such as red meat, organ meats, and seafood, foods that are rich in sugar, high-fructose corn syrup, and alcohol also promote uric acid production and should be avoided or consumed in moderation. Instead, eat a balance of fresh fruits and vegetables, whole grains, and lean protein sources like chicken and fish.
# 3. Limit intake of high-purine foods: Consumption of moderate to large amounts of these foods may trigger gout flares. Limit them to no more than one serving per day.
# - meat: beef, pork, and lamb
# - poultry: turkey and goose
# - seafood: shellfish, anchovies, sardines, trout, and tuna
# - organ meats: liver, kidney, and heart
# - drinks: beer, wine, and liquor (particularly those with high fructose content)
# 4. Drink plenty of water: Water helps the body eliminate excess uric acid more quickly, thereby minimizing the likelihood of gout flares. Make sure to drink at least eight glasses (64 ounces) of water daily.
# 5. Be diligent about taking gout medications: In order for gout medications to be effective, they must be taken as directed by a physician. Regular treatment reduces uric acid levels and prevents gout flares.
# It is essential that individuals take prescribed gout medications and make healthy lifestyle choices to prevent gout flares. If you suffer from gout and have questions or concerns regarding your symptoms or treatment, Gout Treatment Centers can help connect you with qualified physicians in your area who can provide additional guidance. Contact us today at 855.215.2837 to learn more.
#
# One-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How can gout flares be prevented?
# Answer: To prevent gout flares, a gout patient should remain within the target serum uric acid range (less than 6 mg/dL), maintain a healthy weight, limit intake of alcohol, especially beer, and follow a low-purine diet (especially organ meats, such as liver) or a moderate-purine diet (particularly shellfish).
#
# Question: Can medication be use to prevent gout flares?
# Answer: Yes, medication can be used along with lifestyle modifications to prevent gout flares in high risk patients. Medications used to prevent gout flares include allopurinol, febuxostat, and probenecid, along with anti-inflammatory medications called colchicine and nonsteroidal anti-inflammatory drugs (NSAIDs), particularly indomethacin.
#
# Question: Can dietary modifications be used to prevent gout flares?
# Answer: Yes, dietary modifications such as limiting intake of alcohol, particularly beer, and following a low-purine diet (especially organ meats, such as liver) or a moderate-purine diet (particularly shellfish) can be used to prevent gout flares.
#
# Question: Is weight control important in preventing gout flares?
# Answer: Yes, maintaining a healthy weight is important in preventing gout flares because excess body weight can lead to increased uric acid production and reduced uric acid excretion, both of which can contribute to gout.
#
# Question: How does uric acid metabolism contribute to gout?
# Answer: Uric acid is produced during the breakdown of purines, which are found in certain foods and produced naturally in the body. Uric acid is normally excreted in the urine, but if the body produces too much uric acid or does not excrete enough, uric acid can build up and form crystals in the joints and other tissues, leading to gout.
#
# Question: What is the role of acid-base balance in gout?
# Answer: The role of acid-base balance in gout is not well understood, but there is research suggesting that a diet high in acid-forming foods, such as meat, may contribute to lower urinary pH and increased uric acid excretion, which could lead to gout. However, more research is needed to fully understand the relationship between acid-base balance and gout.
#
# Question: Can gout be cured through medication or dietary modifications?
# Answer: Although medication and dietary modifications can help manage gout symptoms and prevent flares, gout itself is not curable. Chronic hyperuricemia, or high levels of uric acid in the blood, can lead to the formation of uric acid deposits in and around joints, causing ongoing inflammation and damage to the joints. However, by managing gout through medication, lifestyle changes, and ongoing monitoring of uric acid levels, the progression and severity of the disease can be controlled.
#
# Few-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical exam, history, blood tests for uric acid, and joint fluid tests.
#
# Question: How can gout flares be prevented?
# Answer: Lifestyle changes, such as maintaining a healthy weight, reducing alcohol consumption, limiting meat intake (especially organ meats), and drinking plenty of water, can help prevent gout flares. Your doctor may also prescribe preventative medication to help reduce the frequency of gout flares.
#
# Question: What medications are commonly prescribed for treating gout?
# Answer: Commonly prescribed medications for treating gout include nonsteroidal anti-inflammatory drugs (NSAIDs), colchicine, corticosteroids, and uricosuric medications (such as probenecid and febuxostat) to lower uric acid levels.
#
# Question: Can gout lead to joint damage or kidney problems?
# Answer: Yes, repeated gout attacks can lead to joint damage and the development of tophi (uric acid deposits in the joints) over time. High uric acid levels can also increase the risk of kidney stones and kidney disease.
#
# Question: Is gout more common in men than women?
# Answer: Yes, gout is more common in men and postmenopausal women due to differences in hormones that impact uric acid metabolism. However, as women age, their risk of gout also increases.
#
# ----- Question: Is gout related to diet? -----
#
# Zero-shot:
#  Question: Is gout related to diet?
# Answer: Yes, gout is a type of arthritis caused by unwanted uric acid crystals forming in the joint, usually in the big toe. Uric acid is produced from foods that contain purines, such as meat, poultry and shellfish. Consuming these foods in excessive amounts can cause the uric acid level in the blood to elevate, which can lead to gout. Limit the consumption of high purine foods, such as organ meats, game meats, sardines, anchovies, and mackerel. A purine-rich drink to avoid is beer, as it can also contribute to increased uric acid levels. Lastly, maintaining a healthy body weight and limiting sugary, high-fructose drinks can prevent gout attacks.
#
# One-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: Is gout related to diet?
# Answer: Yes, gout is related to diet. High levels of uric acid in the blood, called hyperuricemia, can result from eating foods rich in purines (such as organ meats, game meats, and some fish and seafood) and drinking alcohol, especially beer. These foods contribute to increased uric acid production in the body or trips the body's filtering processes, causing uric acid build-up in the joints.
#
# Question: What foods should people with gout avoid?
# Answer: People with gout should avoid foods rich in purines such as red meat, poultry, seafood (such as herring, sardines, mackerel, and anchovies), organ meats (such as liver and kidneys), and gravy, soup, and broth bases made with them. They should also limit their intake of alcohol, especially beer. Low-fat dairy products, such as milk, buttermilk, and yogurt, may help prevent gout attacks.
#
# Question: How can people manage their gout symptoms?
# Answer: People with gout can manage their symptoms by:
#
# - Following a healthcare provider's recommended treatment plan.
# - Maintaining a healthy weight to reduce stress on joints and improve overall health.
# - Drinking plenty of water to help prevent dehydration, which can increase uric acid in the body.
# - Following a low-purine diet or reducing their intake of purine-rich foods.
# - Limiting alcohol intake, especially beer.
# - Taking medication as prescribed by a healthcare provider.
#
# Question: Can gout be prevented?
# Answer: Maintaining a healthy weight, following a low-purine diet, limiting alcohol intake, especially beer, and staying hydrated can help prevent gout. However, gout can be a genetic condition, and people with family members who have gout may have an increased risk, regardless of diet and lifestyle choices.
#
# Question: How should people who think they have gout seek medical advice?
# Answer: People who think they have gout should make an appointment with a healthcare provider for a diagnosis and treatment plan. Prompt medical care may help prevent joint damage and disability that can result from untreated gout. A healthcare provider can also provide recommendations for lifestyle changes and medication to manage gout symptoms.
#
# Question: Can gout spread to other joints?
# Answer: Yes, gout can spread to other joints, particularly those that were previously affected by gout. This is because uric acid crystals can remain in the joint tissues and cause further inflammation and pain. Additionally, if uric acid levels remain high, gout may affect multiple joints simultaneously. Proactive management of gout symptoms with medication and lifestyle changes can help prevent further joint damage.
#
# Question: What are some alternative treatments for gout besides medication?
# Answer: Although medication is a common and effective treatment for gout symptoms, some people may seek alternative or complementary therapies. However, it is essential to discuss such options with a healthcare provider before trying them, as some may be unsafe or not effective for gout management. Some alternative therapies that should be done under the guidance of a healthcare provider include using acupuncture, herbal supplements such as cherries and milk thistle, and mind-body practices such as meditation and yoga to manage gout-related stress.
#
# Few-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical exam, history, blood tests for uric acid, and joint fluid tests.
#
# Question: Is gout related to diet?
# Answer: Gout is related to high levels of uric acid in the body, which is why diet, especially high consumption of purine-containing foods such as red meat, organ meats and shellfish, may trigger gout attacks.
#
# Question: Are there traditional treatments for gout?
# Answer: Yes, the traditional pharmaceutical treatments for gout include NSAIDs (non-steroidal anti-inflammatory drugs), colchicine, and corticosteroids. These drugs suppress the symptoms of gout but do not address the underlying root cause. Due to potential side-effects of long-term use, finding other therapeutic solutions is sought after.
#
# Question: How does Ossome principles help with gout?
# Answer: Ossome principles foster healthy water balance which keeps excess uric acid from over saturating the joints - +6 for gout.
#
# Question: How does the CellCor rectifier work for gout support?
# Answer: The CellCor rectifier potentiates the ability of intercellular water to buffer and transport excess uric acid out of the joints, thereby promoting healthy intercellular water and increased elimination of excess uric acid through normal bodily functions - +7 for gout.
#
# Question: How does Ossome's Cloy calcium support gout?
# Answer: Ossome's Cloy carries calcium to the extracellular fluid where healthy cartilage is formed, and helps maintain a proper calcium/magnesium ratio, which helps protect the joints from gout attack - +8 for gout.
#
# Question: How does Ossome's Calcium Fluoride support gout?
# Answer: Ossome's Calcium Fluoride helps maintain healthy water balance and is able to penetrate joint cartilage, providing further support to resist gout attacks - +9 for gout.
#
# Question: How does L-Glutathione help with gout?
# Answer: L-Glutathione helps support healthy liver and kidney function and helps maintain normal uric acid levels by promoting healthy elimination - +10 for gout.
#
# Question: What are the recommended products for gout +6 thru +10?
# Answer: For those who want to aggressively reduce gout attack frequency, we recommend these Ossome products: Trace Mineral Drops, CellCor rectifier, Cloy calcium, Calcium Fluoride, Precision Calcium, BioAce D3, Full Spectrum Magnesium, Ionic Liquid O2, Ossome Multivitamin, Super Omegas, VeggieTabs or NutriCal, Sard Drops, Enzyme Formula No. 7 and L-Glutathione.
#
# Question: Are there lifestyle changes that can help manage gout?
# Answer: Yes, a healthy low purine diet with five servings of fresh vegetables and fruits daily, drinking plenty of water, maintaining a healthy weight, and moderate alcohol intake is recommended to help manage gout. For answers to gout related FAQs, please visit Ossome's resources page.
#
# ----- Question: Can gout be cured permanently? -----
#
# Zero-shot:
#  Question: Can gout be cured permanently?
# Answer: Gout, like most chronic diseases, cannot be cured permanently. However, it can be effectively managed through lifestyle changes, medication, and a healthy diet. With proper treatment, the frequency and severity of gout attacks can be significantly reduced, and the risk of complications can be minimized. The key to managing gout is to maintain a healthy weight, limit alcohol consumption, avoid purine-rich foods, and adhere to a prescribed treatment plan. While gout cannot be completely eliminated, the goal is to prevent further joint damage and improve overall health and well-being.
#
# One-shot:
#  Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: Can gout be cured permanently?
# Answer: Gout cannot be permanently cured, but it can be effectively managed through lifestyle changes and medication to prevent future attacks and reduce the risk of complications like kidney stones and joint damage.
#
# Question: What lifestyle changes can prevent gout attacks?
# Answer: To prevent gout attacks, it's recommended to maintain a healthy weight, avoid or limit alcohol and sugary drinks, eat a low-purine diet, and manage conditions like hypertension and diabetes. Regular exercise, such as walking, cycling, or swimming, can also help reduce the risk of gout attacks.
#
# Question: What is the role of medications in managing gout?
# Answer: Medications, such as nonsteroidal anti-inflammatory drugs (NSAIDs), colchicine, corticosteroids, and uric acid-lowering drugs, can help relieve symptoms of acute gout attacks, prevent future attacks, and lower uric acid levels in the blood to prevent crystal formation and related complications. The specific medication prescribed will depend on the severity and frequency of gout attacks, as well as individual factors like age, underlying health conditions, and medication allergies.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 58
#      55 print("\nOne-shot:\n", one_res.json()[0]['generated_text'].strip())
#      57 # Few-shot
# ---> 58 few_res = requests.post(url, headers=head, json={"inputs": few_prompt})
#      59 print("\nFew-shot:\n", few_res.json()[0]['generated_text'].strip())
#
# File c:\Program Files\Orange\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Program Files\Orange\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Program Files\Orange\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Program Files\Orange\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Program Files\Orange\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Program Files\Orange\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Program Files\Orange\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Program Files\Orange\Lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\Program Files\Orange\Lib\http\client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File c:\Program Files\Orange\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File c:\Program Files\Orange\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File c:\Program Files\Orange\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Program Files\Orange\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Program Files\Orange\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Evaluating Responses
#
# Create a simple evaluation function to score the responses based on the presence of expected keywords.

# %%
def score_response(response, keywords):
    """Score a response based on the presence of expected keywords"""
    # TODO: Implement the score_response function
    # Example implementation:
    response = response.lower()
    found_keywords = 0
    for keyword in keywords:
        if keyword.lower() in response:
            found_keywords += 1
    return found_keywords / len(keywords) if keywords else 0

# Expected keywords for each question
expected_keywords = {
    "What foods should be avoided by patients with gout?": 
        ["purine", "red meat", "seafood", "alcohol", "beer", "organ meats"],
    "What medications are commonly prescribed for gout?": 
        ["nsaids", "colchicine", "allopurinol", "febuxostat", "probenecid", "corticosteroids"],
    "How can gout flares be prevented?": 
        ["medication", "diet", "weight", "alcohol", "water", "exercise"],
    "Is gout related to diet?": 
        ["yes", "purine", "food", "alcohol", "seafood", "meat"],
    "Can gout be cured permanently?": 
        ["manage", "treatment", "lifestyle", "medication", "chronic"]
}

score_zero = []
score_one = []
score_few = []

for q in qs:
    kwords = expected_keywords[q]

    # Zero-shot
    zp = f"Question: {q}\nAnswer:"
    z = get_llm_response(prompt_text=zp, api_key=api_key)
    s_z = score_response(z, kwords)
    score_zero.append(s_z)

    # One-shot
    op = f"Question: {exs[0][0]}\nAnswer: {exs[0][1]}\n\nQuestion: {q}\nAnswer:"
    o = get_llm_response(prompt_text=op, api_key=api_key)
    s_o = score_response(o, kwords)
    score_one.append(s_o)

    # Few-shot
    fp = (
        f"Question: {exs[0][0]}\nAnswer: {exs[0][1]}\n\n"
        f"Question: {exs[1][0]}\nAnswer: {exs[1][1]}\n\n"
        f"Question: {q}\nAnswer:"
    )
    f = get_llm_response(prompt_text=fp, api_key=api_key)
    s_f = score_response(f, kwords)
    score_few.append(s_f)


print("\n--- Scores by Prompting Strategy ---")
for i in range(len(qs)):
    print(f"\nQuestion: {qs[i]}")
    print(f"Zero-shot score: {score_zero[i]:.2f}")
    print(f"One-shot score:  {score_one[i]:.2f}")
    print(f"Few-shot score:  {score_few[i]:.2f}")

avg_z = sum(score_zero) / len(score_zero)
avg_o = sum(score_one) / len(score_one)
avg_f = sum(score_few) / len(score_few)

print("\n--- Average Scores ---")
print(f"Zero-shot: {avg_z:.2f}")
print(f"One-shot:  {avg_o:.2f}")
print(f"Few-shot:  {avg_f:.2f}")

# best
best = max([("zero-shot", avg_z), ("one-shot", avg_o), ("few-shot", avg_f)], key=lambda x: x[1])[0]
print(f"\nBest strategy overall: {best}")
# Out:
# --- Scores by Prompting Strategy ---
#
# Question: What foods should be avoided by patients with gout?
# Zero-shot score: 0.33
# One-shot score:  0.33
# Few-shot score:  0.33
#
# Question: What medications are commonly prescribed for gout?
# Zero-shot score: 0.50
# One-shot score:  0.50
# Few-shot score:  0.67
#
# Question: How can gout flares be prevented?
# Zero-shot score: 0.00
# One-shot score:  0.50
# Few-shot score:  0.50
#
# Question: Is gout related to diet?
# Zero-shot score: 0.33
# One-shot score:  0.67
# Few-shot score:  0.83
#
# Question: Can gout be cured permanently?
# Zero-shot score: 0.80
# One-shot score:  0.60
# Few-shot score:  0.60
#
# --- Average Scores ---
# Zero-shot: 0.39
# One-shot:  0.52
# Few-shot:  0.59
#
# Best strategy overall: few-shot

# %% [markdown]
# ## 6. Saving Results
#
# Save your results in a structured format for auto-grading.

# %%
with open("results/part_3/prompting_results.txt", "w") as f:
    f.write("question,zero_shot,one_shot,few_shot\n")
    for i in range(len(qs)):
        f.write(f"{qs[i].lower().replace(' ', '_')},{score_zero[i]:.2f},{score_one[i]:.2f},{score_few[i]:.2f}\n")
    
    f.write(f"\naverage,{avg_z:.2f},{avg_o:.2f},{avg_f:.2f}\n")
    f.write(f"best_method,{best}\n")

# %% [markdown]
# ## Progress Checkpoints
#
# 1. **Prompting Templates**:
#    - [ ] Create zero-shot template
#    - [ ] Create one-shot template
#    - [ ] Create few-shot template
#    - [ ] Format templates with questions and examples
#
# 2. **LLM API Integration**:
#    - [ ] Connect to the Hugging Face API
#    - [ ] Test with different prompts
#    - [ ] Handle API errors
#
# 3. **Comparison and Evaluation**:
#    - [ ] Compare strategies on multiple questions
#    - [ ] Score responses based on keywords
#    - [ ] Determine the best strategy
#
# 4. **Results and Documentation**:
#    - [ ] Save results in the required format
#    - [ ] Document your findings
#
# ## What to Submit
#
# 1. Your implementation in a Python script `utils/prompt_comparison.py` that:
#    - Defines the prompting templates
#    - Connects to the Hugging Face API
#    - Compares different prompting strategies
#    - Scores and evaluates the responses
#
# 2. The results of your experiments in `results/part_3/prompting_results.txt` with the format shown above
#
# The auto-grader will check:
# 1. That your results file contains the required sections
# 2. That your scoring logic correctly identifies keyword presence
# 3. That you've correctly calculated average scores
# 4. That you've identified the best performing method
